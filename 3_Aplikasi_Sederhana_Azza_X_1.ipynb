# %% [markdown]
# <a href="https://colab.research.google.com/github/hereszivy/KKA-X-Semester-1-AzzaW.N/blob/main/3_Aplikasi_Sederhana_Azza_X_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama kelompok : Burok keren
#
# Nama: Azza Wahyu Nazila
#
# Kelas: X-1
#
# No Absen: 9

# %% [markdown]
# #Aplikasi Menghitung Luas Persegi Panjang

# %%
print("halo anwar")
# Out:
# halo anwar

# %%
panjang = int(input("Masukkan panjang dari persegi panjang (cm): "))
lebar = int(input ("Masukkan lebar dari persegi panjang (cm): "))

luas = panjang * lebar

print(f"\nLuas dari persegi panjangnya adalah {luas} cm^2.")
# Out:
# Masukkan panjang dari persegi panjang (cm): 8
# Masukkan lebar dari persegi panjang (cm): 9
#
# Luas dari persegi panjangnya adalah 72 cm^2.

# %%
Tinggi = int(input("Masukkan tinggi dari tabung (cm): "))
Jarijari = int(input("Masukkan jari-jari dari tabung (cm): "))
Phi = 22/7

Volume = Phi * Jarijari**2 * Tinggi

print(f"\nVolume dari tabung tersebut adalah {Volume} cm^3.")
# Out:
# Masukkan tinggi dari tabung (cm): 14
# Masukkan jari-jari dari tabung (cm): 7
#
# Volume dari tabung tersebut adalah 2156.0 cm^3.
