# %% [markdown]
# <a href="https://colab.research.google.com/github/hereszivy/KKA-X-Semester-1-AzzaW.N/blob/main/1_Fungsi_print_Azza_X_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama: Azza Wahyu Nazila
#
# Kelas: X-1
#
# No Absen: 9

# %% [markdown]
# #Menampilkan Teks Bebas

# %%
print("Azza Wahyu Nazila")
# Out:
# Azza Wahyu Nazila

# %% [markdown]
# #Menampilkan Nilai Variabel

# %%
nama_idola = "Nadin Amizah"
print(nama_idola)
# Out:
# Nadin Amizah

# %%
usia = 14
print(usia)
# Out:
# 14

# %% [markdown]
# Latihan Soal:
#
# 1. Buat variabel nama saudara & tampilkan
# 2. Buat variabel jumlah saudara & tampilkan

# %%
nama_saudara = "Muhammad Syakil Abyan"
print(nama_saudara)
# Out:
# Muhammad Syakil Abyan

# %%
jumlah_saudara = 2
print(jumlah_saudara)
# Out:
# 2

# %% [markdown]
# #Menampilkan Nilai Variabel dan String

# %%
print("Nama idola saya adalah",nama_idola,". Usianya adalah",usia,"tahun.")
# Out:
# Nama idola saya adalah Nadin Amizah . Usianya adalah 14 tahun.

# %%
print("Nama idola saya adalah "+nama_idola+". Usianya adalah "+str(usia)+"tahun.")
# Out:
# Nama idola saya adalah Nadin Amizah. Usianya adalah 14tahun.

# %%
print(f"Nama idola saya adalah {nama_idola} . Usianya adalah {usia} tahun.")
# Out:
# Nama idola saya adalah Nadin Amizah . Usianya adalah 14 tahun.

# %% [markdown]
# #Escape String

# %%
print("Nama: Azza Wahyu Nazila")
print("Kelas: X.1")
print("No. Absen: 9")
# Out:
# Nama: Azza Wahyu Nazila
# Kelas: X.1
# No. Absen: 9

# %%
print("Nama: Azza Wahyu Nazila\nKelas: X.1\nNo. Absen: 9")
# Out:
# Nama: Azza Wahyu Nazila
# Kelas: X.1
# No. Absen: 9

# %%
print("""Nama\t\t: Azza Wahyu Nazila

Kelas\t\t: X.1

No. Absen\t: 9""")
# Out:
# Nama		: Azza Wahyu Nazila
#
# Kelas		: X.1
#
# No. Absen	: 9

# %%
print("Halo Nama Saya Habib Jafar")
# Out:
# Halo Nama Saya Habib Jafar

# %%
print('Nama Saya Habib Jafar')
# Out:
# Nama Saya Habib Jafar

# %%
print('Halo Nama Saya Habib Ja\'far')
# Out:
# Halo Nama Saya Habib Ja'far

# %%
print("Halo Nama Saya Habib Ja'far")
# Out:
# Halo Nama Saya Habib Ja'far

# %%
print("Bu Shinta berkata, \"Tolong fokus ke TV sejenak.\"")
# Out:
# Bu Shinta berkata, "Tolong fokus ke TV sejenak."

# %%
print('Bu Shinta berkata, "Tolong fokus ke TV sejenak."')
# Out:
# Bu Shinta berkata, "Tolong fokus ke TV sejenak."

# %%
print("Silakan simpan file tugas KKA di folder Local disk D:\\MAN Demak\\KKA\\Tugas")
# Out:
# Silakan simpan file tugas KKA di folder Local disk D:\MAN Demak\KKA\Tugas

# %%
print('Bu Shinta berkata, "Berikut adalah daftar piket harian kelas X.2 yang disimpan di file D:\\Man Demak\\Jadwal piket."\n')
print ("""Senin\t\tSelasa\t\tRabu
Jioelo\t\tHasbi\t\tNaufal
Azam\t\tA'inun\t\tNurul""")
# Out:
# Bu Shinta berkata, "Berikut adalah daftar piket harian kelas X.2 yang disimpan di file D:\Man Demak\Jadwal piket."
#
# Senin		Selasa		Rabu
# Jioelo		Hasbi		Naufal
# Azam		A'inun		Nurul

# %% [markdown]
# #Parameter Fungsi Print

# %%
nama_siswa_1 = "Dias"
nama_siswa_2 = "Disa"

print(nama_siswa_1,end=" ")
print(nama_siswa_2)
# Out:
# Dias Disa

# %%
print(nama_siswa_1, nama_siswa_2)
# Out:
# Dias Disa

# %%
print(nama_siswa_1, nama_siswa_2, sep="-")
# Out:
# Dias-Disa

# %%
nama_siswa_3 = "Kinan"
nama_siswa_4 = "Azka"
nama_siswa_5 = "Naufal"
nama_siswa_6 = "Ridho"

print(nama_siswa_6,nama_siswa_3,nama_siswa_5,nama_siswa_4,nama_siswa_4, sep="/")
# Out:
# Ridho/Kinan/Naufal/Azka/Azka

# %%
print(nama_siswa_4, end="*")
print(nama_siswa_4, end="*")
print(nama_siswa_5, end="*")
print(nama_siswa_3, end="*")
print(nama_siswa_6)
# Out:
# Azka*Azka*Naufal*Kinan*Ridho
